# %%
import pandas as pd
import numpy as np

# %%
suicide_df = pd.read_csv('suicide/tweets.csv')
suicide_df.head()
# Out:
#                     id      conversation_id     created_at        date  \
# 0  1152996044604682241  1152996044604682241  1563730653000  2019-07-21
# 1  1152995993148899329  1152995993148899329  1563730641000  2019-07-21
# 2  1152995985053900800  1152995985053900800  1563730639000  2019-07-21
# 3  1152995984642887683  1152995984642887683  1563730639000  2019-07-21
# 4  1152995955559620608  1152995955559620608  1563730632000  2019-07-21
#
#        time timezone              user_id         username  \
# 0  10:37:33      PDT           2958699552         imonlylj
# 1  10:37:21      PDT             29907109        _kingneal
# 2  10:37:19      PDT  1152971452846694401    ventingbroken
# 3  10:37:19      PDT           2561945708  awesome_thebest
# 4  10:37:12      PDT   891371293563596800          drmo7og
#
#                                              name place  ... likes_count  \
# 0                       Misunderśtøød x Mìdaś ㊗️️   NaN  ...           0
# ...

# %%
suicide_df.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
suicide_df.head()
# Out:
#                     id      time  \
# 0  1152996044604682241  10:37:33
# 1  1152995993148899329  10:37:21
# 2  1152995985053900800  10:37:19
# 3  1152995984642887683  10:37:19
# 4  1152995955559620608  10:37:12
#
#                                                tweet              hashtags  \
# 0                              Suicide Thoughts ....                    []
# 1  If I wake up as a white person in my next life...                    []
# 2  I fixed my bio (Cant add a banner because Twit...                    []
# 3  Weaponizign Suicide disturbs me a lot Cardi B ...                    []
# 4  #sam harcelé par ses camarades de classe se #s...  ['#sam', '#suicide']
#
#   cashtags
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []

# %%
lonely_df = pd.read_csv('lonely/tweets.csv')
lonely_df.head()
# Out:
#                     id      conversation_id     created_at        date  \
# 0  1152982582843326466  1152982582843326466  1563727443000  2019-07-21
# 1  1152982578741284865  1152916420587675648  1563727442000  2019-07-21
# 2  1152982577181024259  1152976191781048322  1563727442000  2019-07-21
# 3  1152982576153239552  1152982576153239552  1563727442000  2019-07-21
# 4  1152982566263296000  1152982566263296000  1563727439000  2019-07-21
#
#        time timezone              user_id        username              name  \
# 0  09:44:03      PDT  1151002890573701120       monbebe93               제시카
# 1  09:44:02      PDT  1065697539259854849   sugarplum_skz       lonely wolf
# 2  09:44:02      PDT   704212959950667776    lonely_walsh         Elizabeth
# 3  09:44:02      PDT            284959188  lonelyoakradio  Lonely Oak radio
# 4  09:43:59      PDT            144328187     noelle_amor             YaYa🌹
#
#   place  ... likes_count         hashtags cashtags  \
# ...

# %%
lonely_df.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
lonely_df.head()
# Out:
#                     id      time  \
# 0  1152982582843326466  09:44:03
# 1  1152982578741284865  09:44:02
# 2  1152982577181024259  09:44:02
# 3  1152982576153239552  09:44:02
# 4  1152982566263296000  09:43:59
#
#                                                tweet         hashtags cashtags
# 0  i dont know why but he looks so lonely in this...               []       []
# 1  Я после того как увидела их начала отращивать ...               []       []
# 2             Even follow you on all social networks               []       []
# 3  #Nowplaying: Garmonsway, Gibbon and Harrington...  ['#nowplaying']       []
# 4  Laying in this hammock every Sunday alone is g...               []       []

# %%
hopeless_df = pd.read_csv('hopeless/tweets.csv')
hopeless_df.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
hopeless_df.head()
# Out:
#                     id      time  \
# 0  1151526536471728134  09:18:15
# 1  1151526442922139649  09:17:52
# 2  1151526396210110464  09:17:41
# 3  1151526283890683904  09:17:15
# 4  1151526267738628097  09:17:11
#
#                                                tweet hashtags cashtags
# 0  Hopeless, crazed, and dispossessed, I walked o...       []       []
# 1           KAP haberini beklerken serSERİn olmuştuk       []       []
# 2                                  17-july-2019. 🦉💛.       []       []
# 3                                      เป็นไรสาวน้อย       []       []
# 4                   انا قاعده اعيش اسعد ايام حياتي💛.       []       []

# %%
depression_df = pd.read_csv('depression/depressive_unigram_tweets.csv')
depression_df.head()
# Out:
# C:\Users\91810\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Unnamed: 0           id      time  \
# 0          0  1.15135E+18  21:25:13
# 1          1  1.15135E+18  21:25:07
# 2          2  1.15135E+18  21:25:06
# 3          3  1.15135E+18  21:24:55
# 4          4  1.15135E+18  21:24:51
#
#                                                tweet  \
# 0  Wow, my dad yday: “you don’t take those stupid...
# 1  what part of this was really harmfult of a lot...
# 2  one of the ways I got through my #depression i...
# 3  see i wanna do one of them but they all say th...
# 4  IS IT clinical depression or is it the palpabl...
#
#                                             hashtags cashtags
# 0                                                 []       []
# ...

# %%
depression_df.drop(['Unnamed: 0'], axis = 1, inplace = True)
depression_df.head()
# Out:
#             id      time                                              tweet  \
# 0  1.15135E+18  21:25:13  Wow, my dad yday: “you don’t take those stupid...
# 1  1.15135E+18  21:25:07  what part of this was really harmfult of a lot...
# 2  1.15135E+18  21:25:06  one of the ways I got through my #depression i...
# 3  1.15135E+18  21:24:55  see i wanna do one of them but they all say th...
# 4  1.15135E+18  21:24:51  IS IT clinical depression or is it the palpabl...
#
#                                             hashtags cashtags
# 0                                                 []       []
# 1                                                 []       []
# 2  ['#depression', '#uncoveringthenewu', '#change...       []
# 3                                                 []       []
# 4                                                 []       []

# %%
depressed_df = pd.read_csv('depressed/tweets.csv')
depressed_df.head()
# Out:
#                     id      conversation_id     created_at        date  \
# 0  1151315262748205057  1151313086525116421  1563329923000  2019-07-16
# 1  1151315254615400448  1151314716091985920  1563329921000  2019-07-16
# 2  1151315222692429825  1151315222692429825  1563329914000  2019-07-16
# 3  1151315218011549696  1151315218011549696  1563329913000  2019-07-16
# 4  1151315209413386240  1151315209413386240  1563329910000  2019-07-16
#
#        time timezone              user_id        username  \
# 0  19:18:43      PDT   930813312786366464    keytodepress
# 1  19:18:41      PDT   771371705063370752        _ron_247
# 2  19:18:34      PDT  1020503873369194496         jan550n
# 3  19:18:33      PDT           2812237658      ran_engbot
# 4  19:18:30      PDT           4833251469  sasstelligence
#
#                             name place  ... likes_count hashtags cashtags  \
# 0                          Cupid   NaN  ...           0       []       []
# ...

# %%
depressed_df.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
depressed_df.head()
# Out:
#                     id      time  \
# 0  1151315262748205057  19:18:43
# 1  1151315254615400448  19:18:41
# 2  1151315222692429825  19:18:34
# 3  1151315218011549696  19:18:33
# 4  1151315209413386240  19:18:30
#
#                                                tweet hashtags cashtags
# 0  Listen!! IM SORRY!!   With her elder spirits g...       []       []
# 1        Im so pissed and depressed at the same time       []       []
# 2  I’m just a hot mess that’s stressed, depressed...       []       []
# 3  Chen's probably depressed too since she's no l...       []       []
# 4  Do you like it when I shake it for ya, daddy? ...       []       []

# %%
antidepressants_df = pd.read_csv('antidepressants/tweets.csv')
antidepressants_df.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
antidepressants_df.head()
# Out:
#                     id      time  \
# 0  1152995178359218176  10:34:06
# 1  1152994945537576960  10:33:11
# 2  1152994834359209985  10:32:44
# 3  1152994452606033920  10:31:13
# 4  1152994432188370949  10:31:08
#
#                                                tweet hashtags cashtags
# 0  i can't think logically and all of shit i say ...       []       []
# 1  Recently moved to Australia and was ASTOUNDED ...       []       []
# 2  Maybe I should go back on my antidepressants. ...       []       []
# 3  What It’s Like to Know You’ll Be on Antidepres...       []       []
# 4                        Do antidepressants work? :/       []       []

# %%
antidepressant_df = pd.read_csv('antidepressant/tweets.csv')
antidepressant_df.drop(['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count'], axis = 1, inplace = True)
antidepressant_df.head()
# Out:
#                     id      time  \
# 0  1152991919137538048  10:21:09
# 1  1152991631722913793  10:20:01
# 2  1152991531789406209  10:19:37
# 3  1152991116733628416  10:17:58
# 4  1152990783420751872  10:16:38
#
#                                                tweet  \
# 0  I hate that the antidepressants made me feel w...
# 1  Your beliefs ultimately are manifested in your...
# 2  I think current trends lead to a world where e...
# 3  Anti-Depressants and Recovery  https://www.mar...
# 4  Have you thought about getting a sleep study d...
#
#                                             hashtags cashtags
# 0                                                 []       []
# 1                                                 []       []
# 2                                                 []       []
# 3  ['#medication', '#antidepressants', '#eatingdi...       []
# 4                                                 []       []

# %%
depressive_twint_tweets_df = pd.concat([suicide_df,lonely_df,hopeless_df,depression_df,depressed_df,antidepressants_df,antidepressant_df], ignore_index = True)
depressive_twint_tweets_df.drop_duplicates()
depressive_twint_tweets_df
# Out:
#                          id      time  \
# 0       1152996044604682241  10:37:33
# 1       1152995993148899329  10:37:21
# 2       1152995985053900800  10:37:19
# 3       1152995984642887683  10:37:19
# 4       1152995955559620608  10:37:12
# ...                     ...       ...
# 246104  1152369599368892416  17:08:17
# 246105  1152369434520104962  17:07:37
# 246106  1152368694263275520  17:04:41
# 246107  1152368663833354241  17:04:34
# 246108  1152367558420340736  17:00:10
#
#                                                     tweet  \
# 0                                   Suicide Thoughts ....
# 1       If I wake up as a white person in my next life...
# 2       I fixed my bio (Cant add a banner because Twit...
# 3       Weaponizign Suicide disturbs me a lot Cardi B ...
# 4       #sam harcelé par ses camarades de classe se #s...
# ...                                                   ...
# 246104  Ha all the fuckers saying I don’t have depress...
# ...

# %%
# export_csv = depressive_twint_tweets_df.to_csv(r'depressive_unigram_tweets_final.csv')

# %%
df = pd.read_csv('depressive_unigram_tweets_final.csv')
df
# Out:
# C:\Users\91810\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,1,2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0 Unnamed: 0.1 cashtags  \
# 0                0            0       []
# 1                1            1       []
# 2                2            2       []
# 3                3            3       []
# 4                4            4       []
# ...            ...          ...      ...
# 2783571     225172          NaN       []
# 2783572     225173          NaN       []
# 2783573     225174          NaN       []
# 2783574     225175          NaN       []
# 2783575     225176          NaN       []
#
#                                                   hashtags           id  \
# 0                                                       []  1.15135E+18
# ...
